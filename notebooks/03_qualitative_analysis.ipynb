# %% [markdown]
# # Qualitative Analysis — 20 cases for the poster
#
# Auto-generated by `src/case_selection.py`. Re-running the script overwrites this file — commit your annotations before regenerating.
#
# **Buckets:**
#
# - **A (5):** Complementary failures — BM25 vs Dense disagree on the gold doc.
# - **B (5):** Entity-Aware lift — Entity hits where Dense misses.
# - **C (5):** BM25 dominance — BM25 hits where both Dense and Entity miss.
# - **D (5):** LLM-only hallucination candidates — large ROUGE-L gap between LLM-only and Dense.
#
# **How to use:** read each case, look at the per-retriever outputs side by side, and fill in the Annotation block. Short notes are fine — we want to put 3–4 cases on the poster.
#
# **Split:** Leonie takes bucket A (cases 1–5), Naeem takes buckets B + C + D (cases 6–20). See `docs/handoff-naeem.md`.
#
# ---
#
# **Heads-up:** generated answers are truncated at 500 characters in this notebook. Some answers (especially list-heavy treatment questions) are several thousand chars long and end in repetition loops. To see the full text for a single case:
#
# ```bash
# uv run python3 -c "
# import json
# qid = '0000281-5'  # replace with the qid you want
# for fn in ['none', 'bm25', 'dense', 'entity']:
#     for line in open(f'results/runs/{fn}.jsonl'):
#         r = json.loads(line)
#         if r['qid'] == qid:
#             print(f'=== {fn.upper()} ({len(r[\"generated_answer\"])} chars) ===')
#             print(r['generated_answer'])
#             print()
#             break
# "
# ```

# %% [markdown]
# ## Case 1 — Bucket A: Complementary failures (BM25 vs Dense)
#
# **qid:** `0000185-8` | **gold_doc:** `0000185` | **qtype:** `treatment` | **source:** `NIDDK`
#
# ### Question
#
# What are the treatments for Hemochromatosis ?
#
# ### Gold answer (truncated)
#
# Health care providers treat hemochromatosis by drawing blood. This process is called phlebotomy. Phlebotomy rids the body of extra iron. This treatment is simple, inexpensive, and safe. Based on the severity of the iron overload, a patient will have phlebotomy to remove a pint of blood once or twice a week for several months to a year, and occasionally longer. Health care providers will test serum ferritin levels periodically to monitor iron levels. The goal is to bring serum ferritin levels to …
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Hemochromatosis is a condition where the body absorbs too much iron, leading to iron overload. Treatments focus on managing the iron levels and preventing complications.
#
# Key treatments include:
#
# *   **Phlebotomy:** Regularly removing blood to remove excess iron. This is the primary treatment.
# *   **Iron chelating agents:** Medications like deferoxamine (Desferal) or deferasirox (Exjade) are used to bind to excess iron and help remove it from the body.
# *   **Dietary restrictions:** Limiting iron…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000067, 0000067, 0000185`
#
# > Based on the passages, the treatments for Hemochromatosis include:
# *   Therapeutic phlebotomy
# *   Iron chelation therapy
# *   Dietary changes
# *   Other treatments
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0002767, 0000067, 0000067`
#
# > Based on the passages, the treatments for hemochromatosis include:
# *   Phlebotomy
# *   Iron chelation therapy
# *   Dietary changes
# *   Treatment for complications
#
# #### **Entity-Aware** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000067, 0002767, 0000067`
#
# > Based on the passages, the treatments for hemochromatosis include:
# * Therapeutic phlebotomy
# * Iron chelation therapy
# * Dietary changes
# * Treatment for complications
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# - **Factually correct?** (per retriever): all yes, same standard treatments (phlebotomy + iron chelation + dietary changes)
# - **Anything hallucinated?**: no ot really. LLM-only adds specific brand drug names (Desferal, Exjade) but those are real iron chelators
# - **Which retriever helps here, and why?**: BM25 finds the gold NIDDK doc via exact match on "Hemochromatosis". Dense + Entity miss the labeled gold but retrieve other NIH docs (NHLBI 0000067, GARD 0002767) that cover the same disease with the same treatments. Their answers are genuinely grounded in retrieval, not just LLM knowledge.
# - **One-line takeaway for the poster**: MedQuAD labels one gold doc per question, but disease coverage overlaps across NIH sources. Doc-level Recall@k undercounts the effective grounding, a Dense "miss" can still produce a faithfully retrieved answer.
# ---

# %% [markdown]
# ## Case 2 — Bucket A: Complementary failures (BM25 vs Dense)
#
# **qid:** `0000592-5` | **gold_doc:** `0000592` | **qtype:** `treatment` | **source:** `GHR`
#
# ### Question
#
# What are the treatments for Lennox-Gastaut syndrome ?
#
# ### Gold answer (truncated)
#
# These resources address the diagnosis or management of Lennox-Gastaut syndrome: - Cleveland Clinic - Genetic Testing Registry: Epileptic encephalopathy Lennox-Gastaut type - National Institute of Neurological Disorders and Stroke: Diagnosis and Treatment of Epilepsy - News Release: FDA Approves New Drug to Treat Severe Form of Epilepsy (U.S. Food and Drug Administration, November 20, 2008) These resources from MedlinePlus offer information about the diagnosis and management of various health con…
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Lennox-Gastaut syndrome (LGS) is a severe form of epilepsy characterized by multiple seizure types, cognitive impairment, and a specific EEG pattern. Treatment is multifaceted and aims to control seizures, improve cognitive function, and manage associated behavioral issues.
#
# Key treatment approaches include:
#
# 1.  **Anti-epileptic Drugs (AEDs):** A combination of multiple AEDs is typically required. Common choices include valproic acid, topiramate, lamotrigine, clobazam, and cannabidiol (CBD). Th…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000179, 0000592, 0000592`
#
# > Based on the passages, treatments for Lennox-Gastaut syndrome include clobazam and anti-epileptic medications such as valproate, lamotrigine, felbamate, or topiramate. There is usually no single antiepileptic medication that will control seizures. Children who improve initially may later show tolerance to a drug or have uncontrollable seizures. The prognosis for individuals with Lennox-Gastaut syndrome varies. There is no cure for the disorder. Complete recovery, including freedom from seizures …
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000179, 0003541, 0000179`
#
# > Based on the passages, treatments for Lennox-Gastaut syndrome include clobazam and anti-epileptic medications such as valproate, lamotrigine, felbamate, or topiramate. There is usually no single antiepileptic medication that will control seizures.
#
# #### **Entity-Aware** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0003541, 0000179, 0000592`
#
# > Based on the passages, the treatments for Lennox-Gastaut syndrome include anti-epileptic medications such as valproate, lamotrigine, felbamate, or topiramate. Clobazam is also mentioned as a treatment. There is usually no single antiepileptic medication that will control seizures. Children may improve initially, but many later show tolerance to a drug or develop uncontrollable seizures.
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# - **Factually correct?** (per retriever): all yes, all correctly name standard LGS treatments (clobazam, valproate, lamotrigine, felbamate, topiramate)
# - **Anything hallucinated?**: no not really, the dru names are real and standard for Lennox-Gastraut
# - **Which retriever helps here, and why?**: BM25 and Entity-Aware find the gold doc via the exact phrase "Lennox-Gastaut syndrome"; Dense misses. But the gold answer is just a list of *pointer references* (Cleveland Clinic, MedlinePlus, etc.) with no actual treatments. All four generated answers are more informative than the gold
# - **One-line takeaway for the poster**: MedQuAD's gold answers for some treatment questions are reference pointers, not content. ROUGE-L penalises good answers in those cases. This likely explains the low ROUGE-L on the `treatment` qtype overall (0.17–0.22).
# ---

# %% [markdown]
# ## Case 3 — Bucket A: Complementary failures (BM25 vs Dense)
#
# **qid:** `0000130-2` | **gold_doc:** `0000130` | **qtype:** `information` | **source:** `NIDDK`
#
# ### Question
#
# What is (are) What I need to know about Hirschsprung Disease ?
#
# ### Gold answer (truncated)
#
# The large intestine, which includes the colon and rectum, is the last part of the digestive tract. The large intestines main job is to absorb water and hold stool. The rectum connects the colon to the anus. Stool passes out of the body through the anus. At birth, the large intestine is about 2 feet long. An adults large intestine is about 5 feet long.
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Hirschsprung disease is a congenital condition where nerve cells (ganglion cells) are missing from part of the colon, causing a bowel obstruction. This leads to symptoms like constipation, abdominal pain, vomiting, and failure to thrive in newborns. It's typically diagnosed through rectal biopsy. Treatment involves surgical removal of the affected colon segment and connection of the healthy colon to the rectum.
#
# #### **BM25** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000035, 0000038, 0000078`
#
# > Based on the provided passages, there is no information about Hirschsprung Disease. The passages discuss diabetes management, kidney disease, and preparing for pregnancy.
#
# #### **Dense** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0002890, 0000481, 0000130`
#
# > Based on the passages:
#
# Hirschsprung disease is a disease of the large intestine or colon. People with this disease do not have the nerve cells in the intestine required to expel stools from the body normally. Symptoms of Hirschsprung disease usually show up in very young children, but sometimes not until adolescence or adulthood. The symptoms may vary with age, but often involve constipation and/or obstruction of the bowel.
#
# Hirschsprung disease is an intestinal disorder characterized by the ab…
#
# #### **Entity-Aware** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000481, 0002890, 0002890`
#
# > Based on the passages, Hirschsprung disease is an intestinal disorder characterized by the absence of nerves in parts of the intestine. This condition occurs when the nerves in the intestine (enteric nerves) do not form properly during development before birth. It is usually identified in the first two months of life, although less severe cases may be diagnosed later. Enteric nerves trigger the muscle contractions that move stool through the intestine. Without these nerves in parts of the intest…
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# - **Factually correct?** (per retriever):
#     - LLM-only: yes, correct Hirschsprung description.
#     - BM25: technically yes, it honestly abstains ("no info in passages") because the retrieved docs are unrelated (diabetes, kidneys, pregnancy). But the user gets no answer.
#     - Dense: yes, finds gold doc + related Hirschsprung docs, gives a correct description.
#     - Entity-Aware: yes, misses gold doc but retrieves other Hirschsprung docs (0000481, 0002890) and gives the same correct description.
# - **Anything hallucinated?**: no, the medical content is accurate in all four (the BM25 astention is correct given its retrieved docs)
# - **Which retriever helps here, and why?**: Dense and Entity both produce correct descriptions. The label gold doc is only found by Dense, but the gold answer itself (an anatomy paragraph about the large intestine) is not adescription of Hirschsprung. Entity's "miss" is again a labeling artifact (see Case 1))
# - **One-line takeaway for the poster**: Two MedQuAD data quality issues in one case: (1) the question is auto-extracted from a brochure title and reads weird; (2) the gold answer is the brochure's background paragraph (large-intestine anatomy), not an actual diseases description. ROUGH-L heavily penalises the correct generated answers, even though three of four retrievers describe Hirschsprung accurately.
#
# ---

# %% [markdown]
# ## Case 4 — Bucket A: Complementary failures (BM25 vs Dense)
#
# **qid:** `0000078-3` | **gold_doc:** `0000078` | **qtype:** `information` | **source:** `NIDDK`
#
# ### Question
#
# What is (are) What I need to know about Gestational Diabetes ?
#
# ### Gold answer (truncated)
#
# Your chances of getting gestational diabetes are higher if you - are overweight - have had gestational diabetes before - have given birth to a baby weighing more than 9 pounds - have a parent, brother, or sister with type 2 diabetes - have prediabetes, meaning your blood glucose levels are higher than normal yet not high enough for a diagnosis of diabetes - are African American, American Indian, Asian American, Hispanic/Latina, or Pacific Islander American - have a hormonal disorder called polyc…
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Gestational diabetes (GDM) is a type of diabetes that develops during pregnancy. It occurs when your body cannot produce enough insulin to keep blood sugar levels in a healthy range.
#
# Here's what you need to know:
#
# *   **What it is:** A specific type of diabetes that develops during pregnancy.
# *   **Why it happens:** Hormones produced during pregnancy can make the body more resistant to insulin, leading to higher blood sugar levels.
# *   **Risk factors:** Family history of diabetes, obesity, prev…
#
# #### **BM25** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000080, 0000035, 0000080`
#
# > Based on the passages, here is the information about "What I need to know about Gestational Diabetes":
#
# *   It is a type of diabetes that develops only during pregnancy.
# *   More information about gestational diabetes is provided in the NIDDK health topic, "What I need to know about Gestational Diabetes".
# *   You can find this information at http://www.niddk.nih.gov/health-information/health-topics/Diabetes/Pages/default.aspx or by calling 18008608747.
#
# The passages do not provide specific detai…
#
# #### **Dense** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000078, 0000078, 0000267`
#
# > Based on the passages, here's what you need to know about Gestational Diabetes:
#
# *   It's a type of diabetes that develops only during pregnancy.
# *   It happens when your body can't make enough insulin during pregnancy.
# *   Insulin is a hormone that helps your body use glucose for energy and controls blood glucose levels.
# *   You will probably be tested for gestational diabetes between weeks 24 and 28 of your pregnancy.
# *   If you have a higher chance of getting gestational diabetes, your doctor…
#
# #### **Entity-Aware** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000078, 0000078, 0000078`
#
# > Based on the passages, here's what you need to know about Gestational Diabetes:
#
# *   It's a type of diabetes that develops only during pregnancy.
# *   It happens when your body can't make enough insulin during pregnancy.
# *   Insulin is a hormone made in your pancreas that helps your body use glucose for energy and control blood glucose levels.
# *   You will probably be tested for gestational diabetes between weeks 24 and 28 of your pregnancy.
# *   If you have a higher chance of getting gestational …
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# - **Factually correct?** (per retriever):
#     - LLM-only: yes, accurate general description of gestational diabetes.
#     - BM25: technically correct but more or less unhelpful, retrieved diabetes-related docs (not the specific GDM brochure), output is mostly "see other resources" with a URL.
#     - Dense: yes, finds gold doc, accurate description.
#     - Entity-Aware: yes, finds gold doc in all 3 chunks, accurate description.
# - **Anything hallucinated?**: no, even BM25's URL is real (from the retrieved passage), not invented
# - **Which retriever helps here, and why?**: Entity-Aware is the cleanest hit (3/3 chunks from gold). Dense + Entity both produce good
#     descriptions. BM25 misses and honestly punts with a redirect.
# - **One-line takeaway for the poster**:  Same MedQuAD artifact as Case 3: brochure-title question, off-topic gold (here a risk-factors list). Generated answers are substantively better than gold; ROUGE-L undercounts them. Entity-Aware's perfect 3/3 chunk hit is wasted on this gold-quality issue.
#
# ---

# %% [markdown]
# ## Case 5 — Bucket A: Complementary failures (BM25 vs Dense)
#
# **qid:** `0000281-5` | **gold_doc:** `0000281` | **qtype:** `treatment` | **source:** `GHR`
#
# ### Question
#
# What are the treatments for desmoid tumor ?
#
# ### Gold answer (truncated)
#
# These resources address the diagnosis or management of desmoid tumor: - Dana-Farber Cancer Institute - Desmoid Tumor Research Foundation: About Desmoid Tumors - Genetic Testing Registry: Desmoid disease, hereditary These resources from MedlinePlus offer information about the diagnosis and management of various health conditions: - Diagnostic Tests - Drug Therapy - Surgery and Rehabilitation - Genetic Counseling - Palliative Care
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Treatment for desmoid tumors depends on the location, size, and whether the tumor is causing symptoms or affecting vital structures. Options include:
#
# *   **Observation:** For small tumors that are not growing or causing symptoms.
# *   **Surgery:** The primary treatment, aiming to remove the tumor completely.
# *   **Radiation Therapy:** Used to shrink the tumor or control growth, often before surgery or if surgery is not possible.
# *   **Systemic Therapy:** Medications like chemotherapy or targeted…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000281, 0000281, 0000281`
#
# > Based on the passages, the treatments for desmoid tumors include surgery and rehabilitation. The passages mention that desmoid tumors can be difficult to remove surgically and often recur. They also mention that these tumors are fibrous, much like scar tissue.
# The passages do not explicitly state the treatments for desmoid tumors. They mention that desmoid tumors can be difficult to remove surgically and often recur. They also mention that these tumors are fibrous, much like scar tissue.
# The pas…
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000003_5, 0000003_5, 0002490`
#
# > Based on the passages, the treatments for desmoid-type fibromatosis include:
# - Observation and possibly surgery at a later time.
# - Chemotherapy.
# - Targeted therapy (imatinib) if the tumor cannot be removed or has come back.
# - A clinical trial of targeted therapy, radiation therapy, and surgery with or without chemotherapy.
# - A clinical trial of targeted therapy (tyrosine kinase inhibitor).
# - Sorafenib may be used to treat desmoid-type fibromatosis.
# - A clinical trial of targeted therapy (tyrosin…
#
# #### **Entity-Aware** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000003_5, 0000003_5, 0000003_5`
#
# > Based on the passages, the treatments for desmoid-type fibromatosis include:
# - Observation and possibly surgery at a later time.
# - Chemotherapy.
# - Surgery to completely remove the tumor when possible.
# - Radiation therapy before or after surgery.
# - Targeted therapy (imatinib) if the tumor cannot be removed or has come back.
# - A clinical trial of targeted therapy, radiation therapy, and surgery with or without chemotherapy.
# - A clinical trial of targeted therapy (tyrosine kinase inhibitor).
# - NSAI…
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# - **Factually correct?** (per retriever):
#     - LLM-only: yes, general overview, all listed treatments real (Observation, Surgery, Radiation, Systemic, Hormone Therapy).
#     - BM25: technically correct ("passages do not explicitly state treatments" is true — gold doc is just a list of resource pointers), but output is a 12× repetition of the same sentence. Unusable.
#     - Dense: yes, substantively the richest answer (Imatinib, Sorafenib, Sulindac, NSAIDs, antiestrogen, tyrosine kinase inhibitors — all real desmoid options). But output degenerates into a repetition loop ("A clinical trial of targeted therapy (tyrosine kinase inhibitor)" × 20+).
#     - Entity: same as Dense, slightly different items in the list, also degenerates into repetition.
# - **Anything hallucinated?**: no. all the drugs and approaches named are real desmoid treatments. the repetition is a generation-quality issue, not a factual one.
# - **Which retriever helps here, and why?**: It depends what you mean by "help". Dense + Entity give the most informative content but formatted badly. LLM-only is cleanest but most general. BM25 finds the gold doc but the gold doc has notreatments to extract. **Recall@3 is the worst metric for this case**, it rewards BM25, which produces the least useful answer.
# - **One-line takeaway for the poster**: this case shows three issues converging: (1) MedQuAD pointer-gold (no treatments in gold); (2) Recall@3 rewards finding a doc that has no answer; (3) `num_predict` cap (S1) cathces the model mid-loop when it tries to list many treatmenents, leaving repetitive output. Together thes make the "best content" retriever (Entity-Aware) look bad on every qunatitative metric while actually providnug the richest information.
#
# ---

# %% [markdown]
# ## Case 6 — Bucket B: Entity-Aware lift over Dense
#
# **qid:** `0000136-5` | **gold_doc:** `0000136` | **qtype:** `treatment` | **source:** `GHR`
#
# ### Question
#
# What are the treatments for branchiootorenal/branchiootic syndrome ?
#
# ### Gold answer (truncated)
#
# These resources address the diagnosis or management of branchiootorenal/branchiootic syndrome: - Gene Review: Gene Review: Branchiootorenal Spectrum Disorders - Genetic Testing Registry: Branchiootic syndrome - Genetic Testing Registry: Branchiootic syndrome 2 - Genetic Testing Registry: Branchiootic syndrome 3 - Genetic Testing Registry: Branchiootorenal syndrome 2 - Genetic Testing Registry: Melnick-Fraser syndrome - MedlinePlus Encyclopedia: Branchial Cleft Cyst - MedlinePlus Encyclopedia: En…
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Treatment for branchiootorenal/branchiootic syndrome depends on the specific type and severity of the condition. There is no cure, but treatments focus on managing symptoms and preventing complications.
#
# **General approaches include:**
#
# * **Managing symptoms:** This may involve medications to control blood pressure, manage kidney function, or address other specific symptoms.
# * **Preventing complications:** This includes regular monitoring of kidney function, blood pressure, and other relevant he…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000136, 0000840, 0000136`
#
# > Based on the passages, the treatments for branchiootorenal/branchiootic syndrome include:
# - Surgery and Rehabilitation
# - Genetic Counseling
# - Palliative Care
# - Diagnostic Tests
# - Drug Therapy
# - Gene Review
# - Genetic Testing Registry
# - MedlinePlus Encyclopedia
# - Gene Review: Branchiootorenal Spectrum Disorders
# - Genetic Testing Registry: Branchiootic syndrome
# - Genetic Testing Registry: Branchiootic syndrome 2
# - Genetic Testing Registry: Branchiootic syndrome 3
# - Genetic Testing Registry: Branchi…
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000840, 0000840, 0000840`
#
# > Based on the passages, treatments for branchiootorenal syndrome may include:
# *   Determining which aids would be most helpful, such as hearing aids or vibrotactile devices.
# *   Cochlear implantation for children over 12 months with severe-to-profound hearing loss.
# *   Early hearing intervention through amplification, surgery, or cochlear implantation for children at risk of hearing loss.
# *   Regular follow-up with a hearing specialist (audiologist) to monitor hearing loss.
# *   Surgery to remove …
#
# #### **Entity-Aware** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000840, 0000840, 0000136`
#
# > Based on the passages, treatments for branchiootorenal/branchiootic syndrome may include:
# *   Surgery to remove anomalies of the neck, such as branchial fistulae or cysts.
# *   Careful assessment and management of hearing loss, which may include hearing aids, vibrotactile devices, or cochlear implantation.
# *   Follow-up by a kidney specialist (nephrologist) for kidney malformations or complications.
# *   In some cases, dialysis or kidney transplant may be required.
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: partial
#   * BM25: partial
#   * Dense:Partial
#   * entity aware:yes
#
# * **Anything hallucinated?**:
#
#   * LLm gives generic treatment recommendations without retrieved evidence and BM25 mostly lists resources/databases instead of concrete treatments and Dense retrieves relevant hearing loss management information but misses broader syndrome management
#
# * **Which retriever helps here, and why?**:
#
#   * entity aware helps most because it retrieves the gold document and provides more syndrome specific treatment information than dense
#
# * **One-line takeaway for the poster**:
#
#   * entity aware retrieval recovers more complete syndromespecific treatment context than standard dense retrieval
#
#
# ---

# %% [markdown]
# ## Case 7 — Bucket B: Entity-Aware lift over Dense
#
# **qid:** `0000757-5` | **gold_doc:** `0000757` | **qtype:** `treatment` | **source:** `GHR`
#
# ### Question
#
# What are the treatments for osteogenesis imperfecta ?
#
# ### Gold answer (truncated)
#
# These resources address the diagnosis or management of osteogenesis imperfecta: - Gene Review: Gene Review: COL1A1/2-Related Osteogenesis Imperfecta - Genetic Testing Registry: Osteogenesis imperfecta - Genetic Testing Registry: Osteogenesis imperfecta type 5 - Genetic Testing Registry: Osteogenesis imperfecta type 6 - Genetic Testing Registry: Osteogenesis imperfecta type 7 - Genetic Testing Registry: Osteogenesis imperfecta type 8 - Genetic Testing Registry: Osteogenesis imperfecta type I - Ge…
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Osteogenesis imperfecta (OI) is a genetic disorder characterized by brittle bones that fracture easily. There is no cure for OI, but treatments focus on managing symptoms and preventing complications. Treatments may include:
#
# *   **Physical therapy:** To maintain muscle strength and flexibility.
# *   **Bone strengthening medications:** Such as pamidronate or zoledronic acid, which can help increase bone density.
# *   **Pain management:** Medications to control bone pain.
# *   **Surgical interventio…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000757, 0004619, 0000757`
#
# > Based on the passages, the treatments for osteogenesis imperfecta are not mentioned. The passages focus on the causes, types, and characteristics of osteogenesis imperfecta, including mutations in specific genes like COL1A1, COL1A2, CRTAP, and P3H1, and the resulting effects on bone structure and strength. There is no information provided about treatments or therapies for this condition.
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000277, 0000667, 0001788`
#
# > Based on the passages, the treatments for osteogenesis imperfecta include exercise, pain medicine, physical therapy, wheelchairs, braces, and surgery.
#
# #### **Entity-Aware** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000757, 0000757, 0000667`
#
# > Based on the passages, the treatments for osteogenesis imperfecta include exercise, pain medicine, physical therapy, wheelchairs, braces, and surgery.
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: yes
#   * BM25:no
#   * Dense: partial
#   * Entity-Aware:yes
#
# * **Anything hallucinated?**:
#
#   * LLM adds treatment details without retrieval grounding, although they are medically plausible and BM25 incorrectly states that no treatment information is provided and Dense retrieves relevant treatment information but misses the gold document
#
# * **Which retriever helps here, and why?**:
#
#   * EntityAaware helps most because it retrieves the gold document while also producing a concise and relevant treatment oriented answer
#
# * **One-line takeaway for the poster**:
#
#   * EntityAaware retrieval recovers relevant treatment context that Dense retrieval partially misses while BM25 fails despite retrieving the gold document
#
# ---

# %% [markdown]
# ## Case 8 — Bucket B: Entity-Aware lift over Dense
#
# **qid:** `0000041-5` | **gold_doc:** `0000041` | **qtype:** `treatment` | **source:** `GHR`
#
# ### Question
#
# What are the treatments for alpha-1 antitrypsin deficiency ?
#
# ### Gold answer (truncated)
#
# These resources address the diagnosis or management of alpha-1 antitrypsin deficiency: - Alpha-1 Foundation: Testing for Alpha-1 - Cleveland Clinic Respiratory Institute - Gene Review: Gene Review: Alpha-1 Antitrypsin Deficiency - GeneFacts: Alpha-1 Antitrypsin Deficiency: Diagnosis - GeneFacts: Alpha-1 Antitrypsin Deficiency: Management - Genetic Testing Registry: Alpha-1-antitrypsin deficiency - MedlinePlus Encyclopedia: Alpha-1 antitrypsin deficiency - MedlinePlus Encyclopedia: Pulmonary func…
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Treatment for alpha-1 antitrypsin deficiency (AATD) depends on the individual's age, symptoms, and the severity of the condition.
#
# **General approaches include:**
#
# *   **Lifestyle modifications:** Smoking cessation is crucial as smoking accelerates lung damage.
# *   **Medications:**
#     *   **Bronchodilators:** To help open airways.
#     *   **Corticosteroids:** To reduce inflammation.
#     *   **Antibiotics:** To treat lung infections.
#     *   **Other medications:** Depending on the specific sympt…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000041, 0000041, 0000041`
#
# > Based on the passages, the management of alpha-1 antitrypsin deficiency includes:
# - Drug Therapy
# - Surgery and Rehabilitation
# - Genetic Counseling
# - Palliative Care
#
# The passages do not provide specific details about the treatments for alpha-1 antitrypsin deficiency.
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000254, 0000001, 0000023`
#
# > Based on the passages, treatments for alpha-1 antitrypsin deficiency include:
# *   Standard therapy for COPD and other related lung diseases, such as bronchodilators and inhaled steroids.
# *   Intravenous augmentation therapy (regular infusion of purified, human AAT) for people with established fixed airflow obstruction.
# *   Lung transplantation for people with end-stage lung disease.
# *   Liver transplantation for advanced liver disease.
# *   Treatment for panniculitis with dapsone or doxycycline t…
#
# #### **Entity-Aware** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000254, 0000001, 0000041`
#
# > Based on the passages, treatments for alpha-1 antitrypsin deficiency include:
# *   Standard therapy for COPD and related lung diseases, such as bronchodilators and inhaled steroids.
# *   Intravenous augmentation therapy (regular infusion of purified, human AAT) for people with established fixed airflow obstruction.
# *   Lung transplantation for people with end-stage lung disease.
# *   Liver transplantation for advanced liver disease.
# *   Panniculitis may resolve on its own or after dapsone or doxycy…
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: partial
#   * BM25: partial
#   * Dense: yes
#   * Entity-Aware: yes
#
# * **Anything hallucinated?**:
#
#   * LLM provides medically plausible treatment details without retrieval grounding and bm25 retrieves the gold document but gives only broad management categories without concrete treatment details
#
# * **Which retriever helps here, and why?**:
#
#   *  entity aware retrieves gold doc (which Dense misses) while also pulling the same content-rich neighbors as Dense producing an equally good answer with better doc coverage
#
# * **One-line takeaway for the poster**:
#
#   *  entityaware retrieval matches Dense's answer quality while also recovering the gold doc making it strictly better on both recall and response accuracy
#
#
# ---

# %% [markdown]
# ## Case 9 — Bucket B: Entity-Aware lift over Dense
#
# **qid:** `0000873-5` | **gold_doc:** `0000873` | **qtype:** `treatment` | **source:** `GHR`
#
# ### Question
#
# What are the treatments for retroperitoneal fibrosis ?
#
# ### Gold answer (truncated)
#
# These resources address the diagnosis or management of retroperitoneal fibrosis: - Johns Hopkins Medicine These resources from MedlinePlus offer information about the diagnosis and management of various health conditions: - Diagnostic Tests - Drug Therapy - Surgery and Rehabilitation - Genetic Counseling - Palliative Care
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Retroperitoneal fibrosis is a condition characterized by the proliferation of fibrous tissue in the retroperitoneum, the space behind the abdominal cavity. Treatment depends on the severity and cause of the fibrosis.
#
# Common treatments include:
#
# *   **Medical management:** This often involves using medications to reduce inflammation and suppress the immune system. Corticosteroids (like prednisone) are frequently used. Other immunosuppressants like azathioprine or mycophenolate mofetil may be use…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0005345, 0000873, 0005345`
#
# > Based on the passages, treatments for retroperitoneal fibrosis may include: Corticosteroid therapy, Tamoxifen, Surgery, and Stents. Corticosteroids are often tried first and are tapered slowly. Other medicines to suppress the immune system, such as mycophenolate mofetil, methotrexate, azathioprine, cyclophosphamide, or tamoxifen, can be prescribed alone or in combination with corticosteroids. If medicine does not work, surgery and stents (draining tubes) are considered. Stents may provide short-…
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0005345, 0005345, 0005345`
#
# > Based on the passages, the treatments for retroperitoneal fibrosis may include: Corticosteroid therapy, Tamoxifen, Surgery, and Stents. Corticosteroids are often tried first and are tapered slowly. Other medicines like mycophenolate mofetil, methotrexate, azathioprine, cyclophosphamide, or tamoxifen can be used alone or with corticosteroids. If medicine does not work, surgery and stents (draining tubes) are considered. Stents may provide short-term relief.
#
# #### **Entity-Aware** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0005345, 0000873, 0005345`
#
# > Based on the passages, treatments for retroperitoneal fibrosis may include: Corticosteroid therapy, Tamoxifen, Surgery, and Stents. Corticosteroids are often tried first and are tapered slowly. Other medicines like mycophenolate mofetil, methotrexate, azathioprine, cyclophosphamide, or tamoxifen can be used alone or with corticosteroids. If medicine doesn't work, surgery and stents (draining tubes) are considered. Stents may provide short-term relief.
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: partial
#   * BM25: yes
#   * Dense: yes
#   * Entity-Aware: yes
#
# * **Anything hallucinated?**:
#
#   * LLM adds azathioprine and mycophenolate mofetil without retrieval support  plausible but ungrounded
#
# * **Which retriever helps here, and why?**:
#
#   * Entit aware helps most because it retrieves the gold document while preserving the same high-quality treatment information retrieved by dense
#
# * **One-line takeaway for the poster**:
#
#   * EntityAware retrieval improves document recall while maintaining strong answer quality comparable to dense retrieval
#
# ---

# %% [markdown]
# ## Case 10 — Bucket B: Entity-Aware lift over Dense
#
# **qid:** `0000008-12` | **gold_doc:** `0000008` | **qtype:** `information` | **source:** `NIHSeniorHealth`
#
# ### Question
#
# What is (are) Breast Cancer ?
#
# ### Gold answer (truncated)
#
# When cancer spreads from its original location in the breast to another part of the body such as the brain, it is called metastatic breast cancer, not brain cancer. Doctors sometimes call this "distant" disease.
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Breast cancer is a type of cancer that starts in the cells of the breasts. It can occur in both women and men, although it is much more common in women. Breast cancer can develop in the lining of milk ducts or in the lobules where milk is produced.
#
# There are several types of breast cancer, including:
#
# *   **Ductal Carcinoma In Situ (DCIS):** This is a non-invasive form of breast cancer that occurs in the milk ducts.
# *   **Invasive Ductal Carcinoma (IDC):** This is the most common type of invasi…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000008, 0000008, 0000027_1`
#
# > Based on the passages, breast cancer is a disease that begins in the cells of the ducts. It can also begin in the lobes or lobules. It is not contagious and not caused by an injury. Breast cancer can spread outside the breast to lymph nodes under the arm, and if it spreads to other parts of the body, it is called metastatic breast cancer. The most common type is ductal carcinoma.
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000027_4, 0000137, 0000027_1`
#
# > Based on the passages, breast cancer is a disease where malignant cells form in the tissues of the breast. It is the second most common type of cancer in American women. The breast is made up of lobes and ducts, which are linked by thin tubes called ducts. Each breast has 15 to 20 sections called lobes, which have many smaller sections called lobules. Lobules end in dozens of tiny bulbs that can make milk. The lobes, lobules, and bulbs are linked by thin tubes called ducts. Each breast also has …
#
# #### **Entity-Aware** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0003978, 0000027_4, 0000008`
#
# > Based on the passages, breast cancer is a disease where malignant cells form in the tissues of the breast. It can occur in the breast itself or in the ducts and lymph nodes surrounding the breast.
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: Partial
#   * BM25: Yes
#   * Dense: Partial
#   * Entity-Aware: Partial
#
# * **Anything hallucinated?**:
#
#   * LLM-only includes additional subtype details (DCIS, IDC) that are not supported by the retrieved evidence
#   * Dense and Entity-Aware miss the gold answer’s main point about metastatic breast cancer terminology
#
# * **Which retriever helps here, and why?**:
#
#   * BM25 helps most because it retrieves the gold document and captures the metastatic spread explanation directly from the source passages
#
# * **One-line takeaway for the poster**:
#
#   * retrieving the gold document alone is not enough  the generation step must also surface the most relevant information from the retrieved context
#
#
#
# ---

# %% [markdown]
# ## Case 11 — Bucket C: BM25 dominance over Dense + Entity
#
# **qid:** `0000219-3` | **gold_doc:** `0000219` | **qtype:** `genetic changes` | **source:** `GHR`
#
# ### Question
#
# What are the genetic changes related to congenital central hypoventilation syndrome ?
#
# ### Gold answer (truncated)
#
# Mutations in the PHOX2B gene cause CCHS. The PHOX2B gene provides instructions for making a protein that acts early in development to help promote the formation of nerve cells (neurons) and regulate the process by which the neurons mature to carry out specific functions (differentiation). The protein is active in the neural crest, which is a group of cells in the early embryo that give rise to many tissues and organs. Neural crest cells migrate to form parts of the autonomic nervous system, many…
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Congenital central hypoventilation syndrome (CCHS) is associated with mutations in the *PTPN13* gene. This gene plays a role in regulating cell growth and differentiation. The most common mutation is a deletion of a specific region within the gene, leading to a truncated protein. Other mutations, such as point mutations or insertions, can also occur. These genetic changes disrupt the normal function of the respiratory control center in the brainstem, leading to impaired breathing.
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000219, 0001488, 0000481`
#
# > Based on the passages, the genetic changes related to congenital central hypoventilation syndrome are not explicitly mentioned. The passages discuss the diagnosis and management of CCHS, its signs and symptoms, and its association with other conditions like Hirschsprung disease and Waardenburg syndrome. However, they do not detail the specific genetic changes involved. Therefore, based on the provided passages, there is no information about the genetic changes related to congenital central hypov…
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0001488, 0001488, 0001488`
#
# > Based on the passages, congenital central hypoventilation syndrome (CCHS) is inherited in an autosomal dominant manner. This means that having a change (mutation) in only one copy of the responsible gene in each cell is enough to cause features of the condition. Most people with CCHS have a new (de novo) mutation in the responsible gene (the PHOX2B gene). De novo mutations occur for the first time in the affected person and are not inherited from a parent. Some people with CCHS have a parent wit…
#
# #### **Entity-Aware** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0001488, 0001488, 0001488`
#
# > Based on the passages, the genetic changes related to congenital central hypoventilation syndrome (CCHS) are mutations in the PHOX2B gene. These mutations are inherited in an autosomal dominant manner. Most cases are due to new mutations, meaning they are not inherited from a parent. Some cases involve germline mosaicism or somatic mosaicism in parents.
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: no
#   * BM25: partial
#   * Dense: partial
#   * Entity-Aware: Yeap
#
# * **Anything hallucinated?**:
#
#   * LLM-only incorrectly identifies the PTPN13 gene as the cause of CCHS instead of PHOX2B
#   * bm25 retrieves the gold document but fails to extract the key genetic information from it and Dense retrieves inheritance-related information but misses the main geneticchange explanation
#
# * **Which retriever helps here, and why?**:
#
#   * entity aware helps most because it correctly identifies PHOX2B mutations and captures inheritance details even without retrieving the gold document
#
# * **One-line takeaway for the poster**:
#
#   * entity aware retrieval can recover clinically important genetic level information even when the exact gold document is missed
#
#
# ---

# %% [markdown]
# ## Case 12 — Bucket C: BM25 dominance over Dense + Entity
#
# **qid:** `0000702-3` | **gold_doc:** `0000702` | **qtype:** `genetic changes` | **source:** `GHR`
#
# ### Question
#
# What are the genetic changes related to myoclonic epilepsy myopathy sensory ataxia ?
#
# ### Gold answer (truncated)
#
# MEMSA is caused by mutations in the POLG gene. This gene provides instructions for making one part, the alpha subunit, of a protein called polymerase gamma (pol ). Pol functions in mitochondria, which are structures within cells that use oxygen to convert the energy from food into a form cells can use. Mitochondria each contain a small amount of DNA, known as mitochondrial DNA (mtDNA), which is essential for the normal function of these structures. Pol "reads" sequences of mtDNA and uses them as…
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Myoclonic epilepsy myopathy sensory ataxia is a complex condition involving multiple neurological systems. Genetic changes can contribute to this condition, but the specific mutations are not well-defined.
#
# There is no single gene or set of genes that directly cause all three components (myoclonic epilepsy, myopathy, and sensory ataxia). Instead, these features often arise from mutations in different genes or combinations of genes that affect various parts of the nervous system.
#
# Some potential …
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000702, 0000702, 0000692`
#
# > Based on the passages, the genetic changes related to myoclonic epilepsy myopathy sensory ataxia (MEMSA) are part of a group of conditions called the POLG-related disorders. These conditions feature mutations in the POLG gene.
# The passages do not provide specific details about the genetic changes.
# The passages do not provide specific details about the genetic changes.
# The passages do not provide specific details about the genetic changes.
# The passages do not provide specific details about the ge…
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000818, 0000818, 0000548`
#
# > Based on the passages, the genetic changes related to myoclonic epilepsy myopathy sensory ataxia are not mentioned. The passages focus on PRICKLE1-related progressive myoclonus epilepsy with ataxia and juvenile myoclonic epilepsy.
# The passages do not contain enough information to answer the question.
# The passages do not contain enough information to answer the question.
# The passages do not contain enough information to answer the question.
# The passages do not contain enough information to answer…
#
# #### **Entity-Aware** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000818, 0000818, 0000818`
#
# > Based on the passages, the genetic changes related to PRICKLE1-related progressive myoclonus epilepsy with ataxia involve mutations in the PRICKLE1 gene. These mutations alter the structure of the prickle homolog 1 protein and disrupt its ability to interact with other proteins, which are critical for brain development and function.
# The genetic changes related to myoclonic epilepsy myopathy sensory ataxia are not mentioned in the provided passages.
# The passages mention that PRICKLE1-related prog…
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: no
#   * BM25: partia
#   * Dense: no
#   * Entity-Aware: no
#
# * **Anything hallucinated?**:
#
#   * LLm-onlu claims the condition has no clearly defined genetic cause contradicting the gold answer identifying POLG mutations
#   * Entity Aware incorrectly shifts focus to PRICKLE1 related epilepsy, which is a different disorder
#   * Dense retrieves unrelated epilepsy conditions and fails to answer the question
#
# * **Which retriever helps here, and why?**:
#
#   * bm25 helps most because it retrieves the correct gold document and at least identifies the association with POLG-related disorders, even though the generated answer is incomplete
#
# * **One-line takeaway for the poster**:
#
#   * Exact term retrieval remains important for rare genetic disorders where dense and entity aware retrieval can drift toward semantically related but incorrect diseases
#
#
# ---

# %% [markdown]
# ## Case 13 — Bucket C: BM25 dominance over Dense + Entity
#
# **qid:** `0000272-3` | **gold_doc:** `0000272` | **qtype:** `outlook` | **source:** `NINDS`
#
# ### Question
#
# What is the outlook for Troyer Syndrome ?
#
# ### Gold answer (truncated)
#
# Prognosis varies, although the disease is progressive. Some patients may have a mild form of the disease while others eventually lose the ability to walk normally. Troyer syndrome does not shorten the normal life span.
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > The outlook for Troyer Syndrome (also known as Hypertrophic Osteoarthropathy) varies depending on the underlying cause and the severity of the condition.
#
# *   **If the underlying cause is treated successfully:** The condition may resolve or improve significantly.
# *   **If the underlying cause persists:** The condition may persist or worsen.
# *   **If the condition is severe:** It can lead to complications like bone infections (osteomyelitis), fractures, and joint damage, which can significantly i…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0006224, 0000272, 0006224`
#
# > Based on the passages, the outlook for Troyer Syndrome is that it is progressive, and some patients may have a mild form while others eventually lose the ability to walk normally. Troyer Syndrome does not shorten the normal life span. There are no specific treatments known to prevent or slow the progression of the disease. Treatment aims to relieve symptoms and improve quality of life.
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0006224, 0006224, 0006224`
#
# > Based on the passages, Troyer syndrome is a neurological disorder that typically begins in early childhood. Symptoms include progressive muscle weakness and stiffness in the legs, muscle wasting in the hands and feet, paraplegia, leg contractures, developmental delays, speech difficulty, mood swings, and short stature. Symptoms worsen over time, and most people need a wheelchair by their 50s or 60s. Life expectancy is normal. Treatment is symptomatic and supportive. The outlook for Troyer syndro…
#
# #### **Entity-Aware** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0006224, 0006224, 0006224`
#
# > Based on the passages, the outlook for Troyer syndrome is that most people need a wheelchair by their 50s or 60s. Life expectancy is normal.
# The passages state:
# * "Signs and symptoms typically begin in early childhood and may include progressive muscle weakness and stiffness (spasticity) in the legs; muscle wasting in the hands and feet; paraplegia; leg contractures; developmental delays; speech difficulty; mood swings; and short stature. Symptoms worsen over time, with most people needing a whe…
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: no
#   * BM25: yes
#   * Dense: partial
#   * Entity-Aware: partial
#
# * **Anything hallucinated?**:
#
#   * llm only confuses Troyer syndrome with hypertrophic osteoarthropathy and adds unrelated complications
#   * dense and Entity-Aware use a related neighboring document, so their answers are mostly consistent but not directly grounded in the gold document
#
# * **Which retriever helps here, and why?**:
#
#   * bm25 helps most because it is the only retriever that finds the gold document and directly matches the gold answer, including the key point that life span is not shortened
#
# * **One-line takeaway for the poster**:
#
#   * Bm25 performs best for this rare syndrome name because exact term matching retrieves the gold document while dense and entity-aware retrieval drift to a related neighbor
#
#
# ---

# %% [markdown]
# ## Case 14 — Bucket C: BM25 dominance over Dense + Entity
#
# **qid:** `0000058-12` | **gold_doc:** `0000058` | **qtype:** `information` | **source:** `NIHSeniorHealth`
#
# ### Question
#
# What is (are) Prostate Cancer ?
#
# ### Gold answer (truncated)
#
# Sometimes, cancer cells break away from the malignant tumor in the prostate and enter the bloodstream or the lymphatic system and travel to other organs in the body. When cancer spreads from its original location in the prostate to another part of the body such as the bone, it is called metastatic prostate cancer, not bone cancer. Doctors sometimes call this "distant" disease.
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Prostate cancer is a type of cancer that develops in the prostate, a gland in the male reproductive system. The prostate gland produces seminal fluid that nourishes and transports sperm.
#
# Prostate cancer can be slow-growing and may not cause symptoms for many years. However, it can also be aggressive and spread quickly to other parts of the body.
#
# Risk factors for prostate cancer include:
# * Age
# * Family history of prostate cancer
# * Race (more common in African American men)
# * Diet
# * Obesity
# * Ch…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000058, 0000036_1, 0000036_3`
#
# > Based on the passages, prostate cancer is a type of cancer that starts in the prostate gland. It can spread to other parts of the body, such as the bone, when it is called metastatic prostate cancer. It is the most common nonskin cancer among men in the United States. Prostate cancer occurs more often in African-American men than in white men.
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000036_2, 0000036_1, 0000036_3`
#
# > Based on the passages, Prostate Cancer is a disease in which malignant (cancer) cells form in the tissues of the prostate. The prostate is a gland in the male reproductive system. It lies just below the bladder and in front of the rectum. It is about the size of a walnut and surrounds part of the urethra. The prostate gland produces fluid that makes up part of the semen. As men age, the prostate may get bigger. A bigger prostate may block the flow of urine from the bladder and cause problems wit…
#
# #### **Entity-Aware** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0000036_3, 0000036_2, 0000036_1`
#
# > Based on the passages, Prostate Cancer is a disease in which malignant (cancer) cells form in the tissues of the prostate. The prostate is a gland in the male reproductive system located just below the bladder and in front of the rectum. It is about the size of a walnut and surrounds part of the urethra. The prostate gland produces fluid that makes up part of semen. As men age, the prostate may get bigger. A bigger prostate may block the flow of urine from the bladder and cause problems with sex…
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: partial
#   * BM25: yes
#   * Dense: partial
#   * Entity-Aware: partial
#
# * **Anything hallucinated?**:
#
#   * LLm only adds general risk factors and screening-related information not grounded in retrieved evidence
#   * Dense and Entity Aware focus on general prostate anatomy and disease description while missing the gold answer key point about metastatic prostate cancer terminology
#
# * **Which retriever helps here, and why?**:
#
#   * BM25 helps most because it retrieves the gold document and directly captures the metastatic spread explanation emphasized in the gold answer.
#
# * **One-line takeaway for the poster**:
#
#   * Exact lexical retrieval better captures the key concept in definition-style medical questions, while dense retrieval tends to drift toward broader background information
#
#
# ---

# %% [markdown]
# ## Case 15 — Bucket C: BM25 dominance over Dense + Entity
#
# **qid:** `0000170-5` | **gold_doc:** `0000170` | **qtype:** `treatment` | **source:** `GHR`
#
# ### Question
#
# What are the treatments for cerebrotendinous xanthomatosis ?
#
# ### Gold answer (truncated)
#
# These resources address the diagnosis or management of cerebrotendinous xanthomatosis: - Gene Review: Gene Review: Cerebrotendinous Xanthomatosis - Genetic Testing Registry: Cholestanol storage disease These resources from MedlinePlus offer information about the diagnosis and management of various health conditions: - Diagnostic Tests - Drug Therapy - Surgery and Rehabilitation - Genetic Counseling - Palliative Care
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Cerebrotendinous xanthomatosis (CTX) is a rare genetic disorder characterized by the accumulation of galactolipins in various tissues. The primary treatment for CTX is supportive care, focusing on managing symptoms and preventing complications.
#
# Here are the main treatment approaches:
#
# 1.  **Supportive Care:** This is the cornerstone of management. It includes:
#     *   **Monitoring:** Regular monitoring of neurological function, vision, hearing, and gait.
#     *   **Managing Symptoms:** Treatment…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0001072, 0001072, 0000170`
#
# > Based on the passages, the treatments for cerebrotendinous xanthomatosis are not mentioned. The passages provide information about the causes, symptoms, diagnosis, and genetic testing availability for the condition. There is no mention of treatments in the provided text. Therefore, based on the information given, I cannot answer the question about treatments.
#
# #### **Dense** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0001072, 0001072, 0001072`
#
# > Based on the passages, treatments for cerebrotendinous xanthomatosis may include chenodeoxycholic acid (CDCA), inhibitors of HMG-CoA reductase, coenzyme Q10, and cataract surgery.
#
# #### **Entity-Aware** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `0001072, 0001072, 0001072`
#
# > Based on the passages, treatments for cerebrotendinous xanthomatosis may include chenodeoxycholic acid (CDCA), inhibitors of HMG-CoA reductase, coenzyme Q10, and cataract surgery.
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: no
#   * BM25: partial
#   * Dense: yes
#   * Entity-Aware: Yes
#
# * **Anything hallucinated?**:
#
#   * LLM-only incorrectly describes CTX as involving galactolipin accumulation and focuses mainly on generic supportive care
#   * BM25 retrieves the gold document but fails to extract treatment information from the passages
#
# * **Which retriever helps here, and why?**:
#
#   * Dense and Entity aware help most because they retrieve clinically relevant treatment details such as CDCA therapy and cataract surgery, even without retrieving the gold doc
#
# * **One-line takeaway for the poster**:
#
#   * retrieving the exact gold document is not always necessary if neighboring documents contain richer treatment information for generation
#
# ---

# %% [markdown]
# ## Case 16 — Bucket D: LLM-only hallucination candidate
#
# **qid:** `0002736-1` | **gold_doc:** `0002736` | **qtype:** `information` | **source:** `GARD`
#
# ### Question
#
# What is (are) Hashimoto's syndrome ?
#
# ### Gold answer (truncated)
#
# Hashimotos syndrome is a form of chronic inflammation that can damage the thyroid, reducing its ability to produce hormones (hypothyroidism). An early sign of the condition may be enlargement of the thyroid (called a goiter), which can potentially interfere with breathing or swallowing. Other signs and symptoms may include tiredness, weight gain, thin and dry hair, joint or muscle pain, constipation, cold intolerance, and/or a slowed heart rate. Affected women may have irregular menstrual period…
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Hashimoto's syndrome is an autoimmune disease where the body's own immune system attacks the thyroid gland. This leads to chronic inflammation and often results in hypothyroidism, a condition where the thyroid gland doesn't produce enough thyroid hormones.
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0002735, 0002736, 0002736`
#
# > Based on the passages, Hashimoto's syndrome is a condition associated with autoimmune antibody positivity and autosomal dominant inheritance. It is also linked to Hashimoto thyroiditis. The exact cause is unknown, but it is thought to relate to autoimmune or other autoinflammatory processes. The condition can cluster in families, and having a close relative with Hashimoto's syndrome or another autoimmune disorder likely increases a person's risk of developing the condition.
#
# #### **Dense** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0002736, 0002736, 0002736`
#
# > Based on the passages, Hashimoto's syndrome is a form of chronic inflammation that can damage the thyroid, reducing its ability to produce hormones (hypothyroidism). An early sign of the condition may be enlargement of the thyroid (called a goiter), which can potentially interfere with breathing or swallowing. Other signs and symptoms may include tiredness, weight gain, thin and dry hair, joint or muscle pain, constipation, cold intolerance, and/or a slowed heart rate. Affected women may have ir…
#
# #### **Entity-Aware** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0002736, 0002736, 0002736`
#
# > Based on the passages, Hashimoto's syndrome is an autoimmune disorder that results from a combination of genetic and environmental factors. It involves antibodies attacking the thyroid gland, causing damage and potentially leading to hypothyroidism. It is the most common cause of hypothyroidism in the United States and is more common in women.
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: partial
#   * BM25: partial
#   * Dense: yes
#   * Entity-Aware: partial
#
# * **Anything hallucinated?**:
#
#   * LLM-only is broadly correct but omits important details from the gold answer, such as goiter and specific symptoms
#   * BM25 focuses on autosomal dominant inheritance and family clustering which are not central to the gold answer and likely come from neighboring document 0002735
#
# * **Which retriever helps here, and why?**:
#
#   * Dense helps most because it retrieves the gold document consistently and produces an answer closely aligned with the gold description
#
# * **One-line takeaway for the poster**:
#
#   * Dense performs best for well known conditions when the retrieved passages strongly match the target definition and symptoms
#
#
# ---

# %% [markdown]
# ## Case 17 — Bucket D: LLM-only hallucination candidate
#
# **qid:** `0004384-1` | **gold_doc:** `0004384` | **qtype:** `information` | **source:** `GARD`
#
# ### Question
#
# What is (are) Neuronal ceroid lipofuscinosis 10 ?
#
# ### Gold answer (truncated)
#
# Neuronal ceroid lipofuscinosis 10 (CLN10-NCL) is a rare condition that affects the nervous system. Signs and symptoms of the condition can develop any time from birth to adulthood and may include progressive dementia, seizures, lack of muscle coordination, and vision loss. CLN10-NCL is caused by changes (mutations) in the CTSD gene and is inherited in an autosomal recessive manner. Treatment options are limited to therapies that can help relieve some of the symptoms.
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Neuronal ceroid lipofuscinosis (NCL) is a group of inherited metabolic disorders characterized by the accumulation of lipopigments (lipofuscin) in neurons. NCL type 10 (NCL-10) is a specific subtype.
#
# NCL-10 is associated with mutations in the *TPP1* gene, which encodes the enzyme tripeptidyl peptidase 1 (TPP1). This enzyme is involved in the breakdown of certain proteins.
#
# NCL-10 is characterized by:
#
# *   **Onset:** Typically in infancy or early childhood.
# *   **Symptoms:** Progressive neurodeg…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000584, 0004384, 0000167`
#
# > Based on the passages, Neuronal ceroid lipofuscinosis 10 is a condition that is inherited in an autosomal recessive pattern. It is associated with microcephaly, respiratory insufficiency, and seizures.
#
# #### **Dense** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0004384, 0004383, 0004390`
#
# > [1] Neuronal ceroid lipofuscinosis 10 (CLN10-NCL) is a rare condition that affects the nervous system. Signs and symptoms of the condition can develop any time from birth to adulthood and may include progressive dementia, seizures, lack of muscle coordination, and vision loss. CLN10-NCL is caused by changes (mutations) in the CTSD gene and is inherited in an autosomal recessive manner. Treatment options are limited to therapies that can help relieve some of the symptoms.
#
# #### **Entity-Aware** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0004384, 0004384, 0004390`
#
# > Based on the passages, Neuronal ceroid lipofuscinosis 10 (CLN10-NCL) is a rare condition that affects the nervous system. Signs and symptoms can develop any time from birth to adulthood and may include progressive dementia, seizures, lack of muscle coordination, and vision loss. CLN10-NCL is caused by changes (mutations) in the CTSD gene and is inherited in an autosomal recessive manner. Treatment options are limited to therapies that can help relieve some of the symptoms.
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: no
#   * BM25: partial
#   * Dense: yes
#   * Entity-Aware: yes
#
# * **Anything hallucinated?**:
#
#   * LLM_only incorrectly associates CLN10-NCL with TPP1 mutations instead of the CTSD gene and BM25 retrieves the gold document but produces only a short and incomplete summary of the condition.
#
# * **Which retriever helps here, and why?**:
#
#   * Dense and entity aware help most because they retrieve the gold document and generate answers closely aligned with the gold definition, symptoms, inheritance pattern, and gene association
#
# * **One-line takeaway for the poster**:
#
#   * Retrieval grounding is critical for rare genetic disorders where LLM-only generation can confidently substitute the wrong disease subtype and gene association
#
# ---

# %% [markdown]
# ## Case 18 — Bucket D: LLM-only hallucination candidate
#
# **qid:** `0004201-4` | **gold_doc:** `0004201` | **qtype:** `exams and tests` | **source:** `GARD`
#
# ### Question
#
# How to diagnose Multiple pterygium syndrome Escobar type ?
#
# ### Gold answer (truncated)
#
# How is multiple pterygium syndrome, Escobar type diagnosed? Multiple pterygium syndrome, Escobar type is diagnosed based on signs and symptoms in the patient. This syndrome should be considered in patients with webs across different body joints, particularly if additional signs and symptoms are present (e.g., subtle facial feature differences). Because skeletal birth defects (especially spine defects), are relatively common in Escobar syndrome radiographs of the complete skeleton may be helpful …
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Diagnosis of Escobar type Multiple Pterygium Syndrome (MPS) involves a combination of clinical findings and genetic testing. Key features include:
#
# 1.  **Multiple Pterygium:** The presence of multiple wing-shaped growths on the conjunctiva of the eyes.
# 2.  **Other Systemic Manifestations:** The presence of other systemic symptoms, which can vary but often include:
#     *   **Skeletal abnormalities:** Such as scoliosis, kyphosis, or bone deformities.
#     *   **Neurological issues:** Including seiz…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000693, 0004201, 0004201`
#
# > Based on the passages, multiple pterygium syndrome, Escobar type is diagnosed based on signs and symptoms in the patient. This syndrome should be considered in patients with webs across different body joints, particularly if additional signs and symptoms are present (e.g., subtle facial feature differences). Skeletal birth defects (especially spine defects), are relatively common in Escobar syndrome radiographs of the complete skeleton may be helpful in diagnosis. Genetic testing for multiple pt…
#
# #### **Dense** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0004201, 0004201, 0004201`
#
# > Based on the passages, multiple pterygium syndrome, Escobar type is diagnosed based on signs and symptoms in the patient. This syndrome should be considered in patients with webs across different body joints, particularly if additional signs and symptoms are present (e.g., subtle facial feature differences). Because skeletal birth defects (especially spine defects), are relatively common in Escobar syndrome radiographs of the complete skeleton may be helpful in diagnosis. Genetic testing for mul…
#
# #### **Entity-Aware** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0004201, 0004201, 0004201`
#
# > Based on the passages, multiple pterygium syndrome, Escobar type is diagnosed based on signs and symptoms in the patient. This syndrome should be considered in patients with webs across different body joints, particularly if additional signs and symptoms are present (e.g., subtle facial feature differences). Because skeletal birth defects (especially spine defects), are relatively common in Escobar syndrome radiographs of the complete skeleton may be helpful in diagnosis. Genetic testing for mul…
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: no
#   * BM25: yes
#   * Dense: Yes
#   * Entity-Aware: Yes
#
# * **Anything hallucinated?**:
#
#   * LLM incorrectly interprets 'pterygium' as an eye condition and describes conjunctival growths which is unrelated to Escobar syndrome
#
# * **Which retriever helps here, and why?**:
#
#   * Dense and Entity aware help most because they retrieve the gold document consistently and generate answers closely aligned with the diagnostic criteria in the gold passage
#
# * **One-line takeaway for the poster**:
#
#   * retrieval grounding prevents terminology confusion in rare syndromes where LLM generation can misinterpret medical terms based on common usage
#
# ---

# %% [markdown]
# ## Case 19 — Bucket D: LLM-only hallucination candidate
#
# **qid:** `0000700-1` | **gold_doc:** `0000700` | **qtype:** `information` | **source:** `GARD`
#
# ### Question
#
# What is (are) Best vitelliform macular dystrophy ?
#
# ### Gold answer (truncated)
#
# Best vitelliform macular dystrophy (BVMD) is a slowly progressive form of macular degeneration. It usually begins in childhood or adolescence, but age of onset and severity of vision loss can vary. Affected people first have normal vision, followed by decreased central visual acuity and distorted vision (metamorphopsia). Peripheral vision is not affected. BVMD is usually inherited in an autosomal dominant manner, but autosomal recessive inheritance has been reported. The condition is typically c…
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > (Best vitelliform macular dystrophy) is a genetic eye disorder that affects the macula, the central part of the retina responsible for sharp, detailed vision. It is characterized by the abnormal development of the fovea, the small depression in the center of the macula. This leads to a specific pattern of macular degeneration called "vitelliform" because the affected area resembles the yolk sac of a developing embryo.
#
# Symptoms typically include:
# * Blurred vision
# * Difficulty seeing in dim light…
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0001016, 0000700, 0001016`
#
# > Based on the passages, Best vitelliform macular dystrophy is a genetic eye disorder that can cause progressive vision loss. This disorder affects the retina, specifically a small area near the center of the retina called the macula. The macula is responsible for sharp central vision. Vitelliform macular dystrophy disrupts cells in the macula and causes a fatty yellow pigment (lipofuscin) to build up in cells underlying the macula. Over time, this abnormal accumulation can damage cells critical f…
#
# #### **Dense** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000700, 0000700, 0000700`
#
# > Based on the passages, Best vitelliform macular dystrophy (BVMD) is a slowly progressive form of macular degeneration. It usually begins in childhood or adolescence, but age of onset and severity of vision loss can vary. Affected people first have normal vision, followed by decreased central visual acuity and distorted vision (metamorphopsia). Peripheral vision is not affected. BVMD is usually inherited in an autosomal dominant manner, but autosomal recessive inheritance has been reported. The c…
#
# #### **Entity-Aware** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0000700, 0000700, 0000700`
#
# > Based on the passages, Best vitelliform macular dystrophy (BVMD) is a slowly progressive form of macular degeneration. It usually begins in childhood or adolescence, but age of onset and severity of vision loss can vary. Affected people first have normal vision, followed by decreased central visual acuity and distorted vision (metamorphopsia). Peripheral vision is not affected. BVMD is usually inherited in an autosomal dominant manner, but autosomal recessive inheritance has been reported. The c…
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: partial
#   * BM25: partial
#   * Dense: Yes
#   * Entity-Aware: yes
#
# * **Anything hallucinated?**:
#
#   * LLM-only adds 'difficulty seeing in dim light' which is not supported by the gold answer
#   * BM25 drifts toward neighboring document 0001016 instead of closely following the gold content
#
# * **Which retriever helps here, and why?**:
#
#   * Dense and Entity Aware help most because they retrieve the gold document consistently and generate answers closely aligned with the gold description, symptoms, and inheritance pattern
#
# * **One-line takeaway for the poster**:
#
#   * Retrieval grounding prevents unsupported symptoms and produces answers more closely aligned with the reference description
#
# ---

# %% [markdown]
# ## Case 20 — Bucket D: LLM-only hallucination candidate
#
# **qid:** `0003549-1` | **gold_doc:** `0003549` | **qtype:** `information` | **source:** `GARD`
#
# ### Question
#
# What is (are) Leri Weill dyschondrosteosis ?
#
# ### Gold answer (truncated)
#
# Leri Weill dyschondrosteosis is a skeletal dysplasia characterized by short stature and an abnormality of the wrist bones called Madelung deformity. Short stature is present from birth due to shortening of the long bones in the legs. Madelung deformity typically develops during mid-to-late childhood and may progress during puberty. People with this condition often experience pain in their wrists or arms. The severity of Leri Weill dyschondrosteosis varies among affected individuals, although the…
#
# ### Generated output per retriever
#
# #### **LLM-only** — gold doc in top-3: ✗
#
# _Retrieved doc_ids:_ `(no retrieval)`
#
# > Leri-Weill dyschondrosteosis is a rare genetic disorder characterized by abnormal bone growth, specifically affecting the growth plates in the long bones of the arms and legs. This leads to short stature and a distinctive skeletal deformity known as Madelung's deformity, which involves a sideways curvature of the legs. It is typically inherited in an autosomal dominant pattern.
#
# #### **BM25** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0003549, 0003549, 0006414`
#
# > Based on the passages, Leri Weill dyschondrosteosis is a skeletal dysplasia characterized by short stature and an abnormality of the wrist bones called Madelung deformity. Short stature is present from birth due to shortening of the long bones in the legs. Madelung deformity typically develops during mid-to-late childhood and may progress during puberty. People with this condition often experience pain in their wrists or arms. The severity of Leri Weill dyschondrosteosis varies among affected in…
#
# #### **Dense** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0003549, 0003549, 0005841`
#
# > Based on the passages, Leri Weill dyschondrosteosis is a skeletal dysplasia characterized by short stature and an abnormality of the wrist bones called Madelung deformity. Short stature is present from birth due to shortening of the long bones in the legs. Madelung deformity typically develops during mid-to-late childhood and may progress during puberty. People with this condition often experience pain in their wrists or arms. The severity of Leri Weill dyschondrosteosis varies among affected in…
#
# #### **Entity-Aware** — gold doc in top-3: ✓
#
# _Retrieved doc_ids:_ `0003549, 0003549, 0005841`
#
# > Based on the passages, Leri Weill dyschondrosteosis is a skeletal dysplasia characterized by short stature and an abnormality of the wrist bones called Madelung deformity. Short stature is present from birth due to shortening of the long bones in the legs. Madelung deformity typically develops during mid-to-late childhood and may progress during puberty. People with this condition often experience pain in their wrists or arms. The severity of Leri Weill dyschondrosteosis varies among affected in…
#
# ### Annotation
#
# _Fill in below — these notes feed directly into the poster._
#
# * **Factually correct?** (per retriever):
#
#   * LLM-only: partial
#   * BM25: yes
#   * Dense: yes
#   * Entity-Aware: yes
#
# * **Anything hallucinated?**:
#
#   * LLM incorrectly describes Madelung deformity as a sideways curvature of the legs instead of a wrist deformity
#
# * **Which retriever helps here, and why?**:
#
#   * BM25, Dense, and entity aware all help equally because they retrieve the gold document consistently and generate answers closely aligned with the gold
#
# * **One-line takeaway for the poster**:
#
#   * Retrieval grounding prevents subtle but important medical inaccuracies in rare skeletal disorders
#
#
# ---
